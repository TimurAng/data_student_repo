# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-анализ" data-toc-modified-id="Загрузка-данных-и-анализ-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и анализ</a></span><ul class="toc-item"><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#Подготовьте-данные-к-обучению-модели" data-toc-modified-id="Подготовьте-данные-к-обучению-модели-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовьте данные к обучению модели</a></span><ul class="toc-item"><li><span><a href="#Составим-список-слов,-которые,-могут-попадать-под-юридические-ограничения." data-toc-modified-id="Составим-список-слов,-которые,-могут-попадать-под-юридические-ограничения.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Составим список слов, которые, могут попадать под юридические ограничения.</a></span></li><li><span><a href="#Объеденим-наши-очищенные-данные-от-не-допустимых-запросов-с-оценками-экспертов." data-toc-modified-id="Объеденим-наши-очищенные-данные-от-не-допустимых-запросов-с-оценками-экспертов.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Объеденим наши очищенные данные от не допустимых запросов с оценками экспертов.</a></span></li><li><span><a href="#Сделайте-векторизацию-текстового-описания" data-toc-modified-id="Сделайте-векторизацию-текстового-описания-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Сделайте векторизацию текстового описания</a></span></li><li><span><a href="#Сделайте-векторизацию-изображений-с-использованием-модели-ResNet-из-библиотеки-Keras-или-PyTorch." data-toc-modified-id="Сделайте-векторизацию-изображений-с-использованием-модели-ResNet-из-библиотеки-Keras-или-PyTorch.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Сделайте векторизацию изображений с использованием модели ResNet из библиотеки Keras или PyTorch.</a></span></li></ul></li><li><span><a href="#Объединение-векторов" data-toc-modified-id="Объединение-векторов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Объединение векторов</a></span><ul class="toc-item"><li><span><a href="#Нормализуем-каждый-тип-векторов-отдельно" data-toc-modified-id="Нормализуем-каждый-тип-векторов-отдельно-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Нормализуем каждый тип векторов отдельно</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#Обучение-модели-предсказания-соответствия" data-toc-modified-id="Обучение-модели-предсказания-соответствия-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение модели предсказания соответствия</a></span><ul class="toc-item"><li><span><a href="#Групповое-разделение-(чтобы-одно-фото-не-попало-в-train-и-val)" data-toc-modified-id="Групповое-разделение-(чтобы-одно-фото-не-попало-в-train-и-val)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Групповое разделение (чтобы одно фото не попало в train и val)</a></span></li><li><span><a href="#Полносвязная-нейроная-сеть" data-toc-modified-id="Полносвязная-нейроная-сеть-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Полносвязная нейроная сеть</a></span></li><li><span><a href="#Обучение-на-модели-RandomForest" data-toc-modified-id="Обучение-на-модели-RandomForest-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Обучение на модели RandomForest</a></span></li><li><span><a href="#Обучение-на-модели-CatBoost" data-toc-modified-id="Обучение-на-модели-CatBoost-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Обучение на модели CatBoost</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-тестовых-данных" data-toc-modified-id="Подготовка-тестовых-данных-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Подготовка тестовых данных</a></span></li><li><span><a href="#Функция-тестирования" data-toc-modified-id="Функция-тестирования-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Функция тестирования</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Дополнительно-попробовал-другой-подход,-используем-предобученую-модель-CLIP" data-toc-modified-id="Дополнительно-попробовал-другой-подход,-используем-предобученую-модель-CLIP-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Дополнительно попробовал другой подход, используем предобученую модель CLIP</a></span></li></ul></div>

# %% [markdown]
# # Поиск по изображениям
#
# # Описание проекта
# Вы работаете в фотохостинге для профессиональных фотографов «Со Смыслом» (“With Sense”).
# Ваши пользователи размещают свои фотографии на хостинге и сопровождают их полным описанием: указывают место съёмок, модель камеры и т. д. Отличительная особенность сервиса — описание: его может предоставить не только тот, кто размещает фотографию, но и другие пользователи портала. <br>
#
# Ваш отдел занимается экспериментом по разработке поиска референсных фотографий для фотографов. Суть поиска заключается в следующем: пользователь сервиса вводит описание нужной сцены. Сервис выводит несколько фотографий с такой же или похожей сценой.
#
# # Задача
# Чтобы эксперимент получил право на жизнь, нужно защитить его перед руководителем компании. Для защиты необходимо презентовать так называемый PoC (Proof of Concept, Проверка концепции) — продемонстрировать, что такой проект практически осуществим. Вам поручено разработать демонстрационную версию поиска изображений по запросу.
# Для демонстрационной версии нужно выбрать лучшую  модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — и покажет, насколько текст и картинка подходят друг другу.
# На основе лучшей модели можно будет собрать предварительную версию продукта, которую вы покажете руководителю компании.
#
# # Описание данных
#
# * В файле **`train_dataset.csv`** находится информация, необходимая для обучения:
#   * имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат **<имя файла изображения>#<порядковый номер описания>**.
# * В папке **`train_images`** содержатся изображения для тренировки модели.
# * В файле **`CrowdAnnotations.tsv`**  — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#   1. Имя файла изображения.
#   2. Идентификатор описания.
#   3. Доля людей, подтвердивших, что описание соответствует изображению.
#   4. Количество человек, подтвердивших, что описание соответствует изображению.
#   5. Количество человек, подтвердивших, что описание не соответствует изображению.
# * В файле **`ExpertAnnotations.tsv`**  — данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#   1. Имя файла изображения.
#   2. Идентификатор описания.
#   3. 4, 5 — оценки трёх экспертов. <br>
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
# * В файле **`test_queries.csv`** находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат **<имя файла изображения>#<порядковый номер описания>**.
# * В папке **`test_images`** содержатся изображения для тестирования модели.

# %% [markdown]
# Ссылка на данные
# https://drive.google.com/drive/folders/1zzZ58ktkG10jG-avJiidny6CjtqDLjU5?usp=sharing

# %% [markdown]
# ## Загрузка данных и анализ

# %%
#!pip install tensorflow -q
#!pip install pymystem3 -q
#!pip install nltk -q
# !pip install catboost -q
# !pip install faiss-cpu -q

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
from PIL import Image
from IPython.display import display
import nltk

#from pymystem3 import Mystem
from nltk.corpus import stopwords as nltk_stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GroupShuffleSplit
#from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, KFold, PredefinedSplit
from sklearn.pipeline import Pipeline
from scipy.stats import randint, uniform


import torch.nn as nn
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import Normalizer
from torch.optim import Adam

from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.applications import ResNet50
#from tensorflow.keras.callbacks import EarlyStopping
#from sklearn.decomposition import PCA
#from tensorflow.keras.applications.resnet50 import preprocess_input
from sentence_transformers import SentenceTransformer, util

import faiss
from tqdm import tqdm

# %%
data_path = '/content/drive/MyDrive/datasets/sbor_4/to_upload'

df_train = pd.read_csv(f'{data_path}/train_dataset.csv')
df_test_q = pd.read_csv(f'{data_path}/test_queries.csv', sep='|', index_col=0)
df_test_i = pd.read_csv(f'{data_path}/test_images.csv')
df_croud = pd.read_csv(f'{data_path}/CrowdAnnotations.tsv', sep='\t', header=None)
df_expert = pd.read_csv(f'{data_path}/ExpertAnnotations.tsv', sep='\t', header=None)

train_images = f'{data_path}/train_images'
test_images = f'{data_path}/test_images'

# %%
def ida(a):
    display(a.head())
    print()
    print(a.info())
    print()
    print(a.isnull().sum())

# %%
ida(df_train)

# %%
ida(df_test_q)

# %%
ida(df_test_i)

# %%
ida(df_croud)
display(df_croud[2].value_counts())

# %% [markdown]
# Доля потвержденных описаний с порогом выше 0.6 составляет всего 5.6% от 47830, что может нам говорить об отсутсвии пользы от этих данных. Посмотрим далее на экспертные оценки описаний.

# %%
ida(df_expert)

# %% [markdown]
# Обработаем наши данные, удалив строки с различными уникальными оценками от 3 экспертов, оставим только те строки где есть хотя бы одно совпадение. Создадим нормализованную оценку (0-1) для регрессии.

# %%
df_expert = df_expert[df_expert[[2, 3, 4]].nunique(axis=1) <= 2].copy()

df_expert['final'] = df_expert[[2, 3, 4]].mode(axis=1)[0]

df_expert['score_norm'] = (df_expert['final'] - 1) / 3
df_expert = df_expert.rename(columns={0: 'image', 1: 'query_id'})

# %%
print('Экспертные оценки после обработки:')
print(df_expert[['image', 'query_id', 'final', 'score_norm']].head())
print(f'\nРаспределение score_norm:')
print(df_expert['score_norm'].value_counts())

# %% [markdown]
# Грубо говоря, идеально подходящих описаний к какртинкам всего 311, приемлемых 492, все остальное не подходит по описанию. В итоге подходящих описаний по статистике экспертов у нас всего 14%.

# %%
df_grouped = df_train.groupby('image')['query_text'].agg(list).reset_index()
df_grouped['desc_count'] = df_grouped['query_text'].apply(len)

print(df_grouped['desc_count'].describe())
print(f'\nВсего уникальных фото: {len(df_grouped)}')
print(f'Всего описаний: {df_grouped['desc_count'].sum()}')

# %% [markdown]
# Всего уникальных фото 1000, как мы видим описаний к ним от 2 до 10шт

# %% [markdown]
# Сгруппируем описания по фото и выведем для наглядности 10 фото с их описанием

# %%
def load_train(path):
    df = pd.read_csv(f'{data_path}/train_dataset.csv')

    df_grouped = df.groupby('image')['query_text'].agg(list).reset_index()

    datagen = ImageDataGenerator(rescale=1./255)

    train_data = datagen.flow_from_dataframe(
        dataframe=df_grouped,
        directory=f'{data_path}/train_images',
        x_col='image',
        y_col='query_text',
        target_size=(224, 224),
        batch_size=16,
        class_mode='raw',
        seed=12345
    )
    return train_data

features, target = next(load_train(data_path))

fig, axes = plt.subplots(10, 2, figsize=(12, 30))

for i in range(10):
    axes[i, 0].imshow(features[i])
    axes[i, 0].set_xticks([])
    axes[i, 0].set_yticks([])

    axes[i, 1].axis('off')

    if isinstance(target[i], list):
        texts = target[i][:10]
        display_text = '\n\n'.join([f'{j+1}. {t[:100]}' for j, t in enumerate(texts)])
    else:
        display_text = str(target[i])

    axes[i, 1].text(0, 0.5, display_text, fontsize=8, wrap=True,
                    verticalalignment='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# Как наглядно видно выше:
# 1. на фото присутствует запрещенный контент (дети)
# 2. из описаний к фото видно что не зачастую очень много не совпадений и никакой связи с изображением. ПОтребуется фильтрация фотогорафий и тщательная отборка описаний.

# %% [markdown]
# Тоже самое сделаем для тестовой выборки

# %%
def load_test(path):
    df = pd.read_csv(f'{data_path}/test_queries.csv', sep='|', index_col=0)

    df_grouped_test = df.groupby('image')['query_text'].agg(list).reset_index()

    datagen = ImageDataGenerator(rescale=1./255)

    test_data = datagen.flow_from_dataframe(
        dataframe=df_grouped_test,
        directory=f'{data_path}/test_images',
        x_col='image',
        y_col='query_text',
        target_size=(224, 224),
        batch_size=16,
        class_mode='raw',
        seed=12345
    )
    return test_data

features, target = next(load_test(data_path))

fig, axes = plt.subplots(10, 2, figsize=(12, 30))

for i in range(10):
    axes[i, 0].imshow(features[i])
    axes[i, 0].set_xticks([])
    axes[i, 0].set_yticks([])

    axes[i, 1].axis('off')

    if isinstance(target[i], list):
        texts = target[i][:10]
        display_text = '\n\n'.join([f'{j+1}. {t[:100]}' for j, t in enumerate(texts)])
    else:
        display_text = str(target[i])

    axes[i, 1].text(0, 0.5, display_text, fontsize=8, wrap=True,
                    verticalalignment='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# Как мы наглядно видим из выведенных тетсовоых фото и описаний к ним, то тут почти идеальное соотвтетсвие. Единственный недостаток это наличие фотографий с детьми.

# %% [markdown]
# ### Промежуточный вывод
#
# 1. Загрузка данных прошла успешно. Пропуски в данных отстутсвуют.
# 2. Судя по распределению оценок описаний в файле CrowdAnnotations.tsv его использование для обучения модели не принесет пользы, будем использовать оценки экспертов.
# 3. судя по выгруженным фото из тренировочной выборки с описанием к ним мы видим что зачастую описания не совпадают со смыслом изображений на фото. К тому же на фото присутсвуют дети, и придется с этим поработать чтобы при запросе не было вывода детей вплоть до возраста 16 лет.
# 4. В тестовой выборке практически идеальное соотвтетсвие описания к фото.

# %% [markdown]
# ## Подготовьте данные к обучению модели

# %% [markdown]
# ### Составим список слов, которые, могут попадать под юридические ограничения.

# %%
words = ['boy', 'girl', 'child', 'toddler', 'kid', 'baby', 'infant', 'teens', 'adolescents',
          'youngster', 'offspring', 'boys', 'girls', 'children', 'teenager', 'newborns',
         'teen', 'adolescent', 'youth', 'toddlers', 'kids', 'babies', 'infants', 'newborn',
         'youngsters', 'offsprings', 'teenagers', 'minor', 'minors', 'youth', 'youths',
         'schoolboy', 'schoolgirl', 'schoolchild', 'pupil', 'pupils']

# %%
pattern = '|'.join(words)
mask = ~df_train['query_text'].str.contains(pattern, case=False, na=False, regex=True)
#inverse_mask = ~mask
df_without_children = df_train[mask]

# %%
ida(df_without_children)

# %% [markdown]
# ### Объеденим наши очищенные данные от не допустимых запросов с оценками экспертов.

# %%
df_train_labeled = df_without_children.merge(
    df_expert[['image', 'query_id', 'final', 'score_norm']],
    on=['query_id', 'image'],
    how='inner'
)

df_train_labeled.head()

# %%
df_train_labeled.shape

# %% [markdown]
# ### Сделайте векторизацию текстового описания

# %%
sbert = SentenceTransformer('all-MiniLM-L6-v2')

# Получаем эмбеддинги
sbert_train = sbert.encode(df_train_labeled['query_text'].tolist())
print(f'SBERT эмбеддинги: {sbert_train.shape}')

# Для теста
sbert_test = sbert.encode(df_test_q['query_text'].tolist())
print(f'Тестовые SBERT: {sbert_test.shape}')

# %%
print(f'Форма SBERT_train матрицы: {sbert_train.shape}')
print(f'Форма SBERT_test матрицы: {sbert_test.shape}')

# %% [markdown]
# ### Сделайте векторизацию изображений с использованием модели ResNet из библиотеки Keras или PyTorch.

# %%
class ImageDatasetFromDataFrame(Dataset):
    def __init__(self, dataframe, img_dir, transform=None):

        self.dataframe = dataframe
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx]['image']
        img_path = os.path.join(self.img_dir, img_name)

        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image

def load_images_pytorch(df, img_dir, batch_size=32):

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomAffine(0, translate=None, scale=(0.9, 1.1)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                           std=[0.229, 0.224, 0.225])
    ])

    dataset = ImageDatasetFromDataFrame(
        dataframe=df,
        img_dir=img_dir,
        transform=transform
    )

    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4
    )

    return dataloader

feature_extractor = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

num_features = feature_extractor.fc.in_features
feature_extractor.fc = torch.nn.Identity()

feature_extractor.eval()

for param in feature_extractor.parameters():
    param.requires_grad = False

img_gen = load_images_pytorch(df_train_labeled, f'{data_path}/train_images')

all_features = []
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
feature_extractor = feature_extractor.to(device)

with torch.no_grad():
    for batch_images in img_gen:
        batch_images = batch_images.to(device)
        batch_features = feature_extractor(batch_images)
        all_features.append(batch_features.cpu())

features = torch.cat(all_features, dim=0).numpy()
print()
print(f'Форма эмбедингов изображений: {features.shape}')

# %% [markdown]
# Таким образом
#
# 1. **`df_without_children`** — фильтрация по словам (удалены запросы, связанные с детьми)
# 2.	Объединение с экспертными оценками — остаются только пары с оценками
# 3.	Векторизация — только для фото, у которых есть описания после фильтрации

# %% [markdown]
# ## Объединение векторов
#
# Подготовьте данные для обучения: объедините векторы изображений и векторы текстов с целевой переменной.

# %% [markdown]
# ### Нормализуем каждый тип векторов отдельно

# %%
text_norm = Normalizer(norm='l2').fit_transform(sbert_train)
image_norm = Normalizer(norm='l2').fit_transform(features)

# %%
X_text = sbert_train
print(f'Текстовые признаки: {X_text.shape}')
print(f'  min = {X_text.min():.4f}, max = {X_text.max():.4f}')
print()

# %%
X_combined = np.hstack([text_norm, image_norm])
print(f'Объединенные признаки: {X_combined.shape}')
print()

y = df_train_labeled['score_norm'].values
print(f'Целевая метка: {y.shape}')

# %% [markdown]
# ### Промежуточный вывод
#
# На данном этапе мы подготовли данные к обучению
# 1. Составили список стоп-слов и маску для очистки запросов от запрещенных к показу фотографий и произвели фильтрацию.
# 2. Произвели агрегацию экспертных оценок и соеденили с тренировочным датасетом почсле фильтрации
# 3. Произвели векторизацию изображений с помощью Resnet50, а текста с помощью sBert для того чтобы модель лучше улавливала смысл слов и различия.
# 4. Объеденили вектора предварительно произведя масштабирование и нормализацию.

# %% [markdown]
# ## Обучение модели предсказания соответствия

# %% [markdown]
# ### Групповое разделение (чтобы одно фото не попало в train и val)

# %%
gss = GroupShuffleSplit(n_splits=1, train_size=0.7, random_state=42)
groups = df_train_labeled['image']

train_idx, val_idx = next(gss.split(X_combined, y, groups=groups))

X_train, X_val = X_combined[train_idx], X_combined[val_idx]
y_train, y_val = y[train_idx], y[val_idx]

print(f"Train: {len(train_idx)} примеров")
print(f"Val: {len(val_idx)} примеров")

# %% [markdown]
# ### Полносвязная нейроная сеть

# %%
class RegressionModel(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.LayerNorm(64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 32),
            nn.LayerNorm(32),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.net(x)

def train_model(model, X_train, y_train, X_val, y_val, epochs=500, batch_size=16, lr=0.0005, patience=50):

    train_dataset = TensorDataset(
        torch.tensor(X_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.float32)
    )
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    optimizer = Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    criterion = nn.MSELoss()

    best_val_mae = float('inf')
    patience_counter = 0
    best_weights = None

    history = {'mae': [], 'val_mae': [], 'loss': [], 'val_loss': []}

    for epoch in range(epochs):
        model.train()
        train_losses = []
        train_maes = []

        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            y_pred = model(X_batch).squeeze()
            loss = criterion(y_pred, y_batch)
            loss.backward()
            optimizer.step()

            train_losses.append(loss.item())
            train_maes.append(torch.mean(torch.abs(y_pred - y_batch)).item())

        avg_train_mae = np.mean(train_maes)
        avg_train_loss = np.mean(train_losses)

        model.eval()
        with torch.no_grad():
            y_val_pred = model(torch.tensor(X_val, dtype=torch.float32)).squeeze()
            val_loss = criterion(y_val_pred, torch.tensor(y_val, dtype=torch.float32)).item()
            val_mae = torch.mean(torch.abs(y_val_pred - torch.tensor(y_val, dtype=torch.float32))).item()

        history['mae'].append(avg_train_mae)
        history['val_mae'].append(val_mae)
        history['loss'].append(avg_train_loss)
        history['val_loss'].append(val_loss)

        print(f'Epoch {epoch+1}/{epochs} - mae: {avg_train_mae:.4f} - val_mae: {val_mae:.4f}')

        if val_mae < best_val_mae:
            best_val_mae = val_mae
            patience_counter = 0
            best_weights = model.state_dict().copy()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f'Early stopping on epoch {epoch+1}')
                break

    model.load_state_dict(best_weights)

    best_epoch = np.argmin(history['val_mae'])
    best_train_mae = history['mae'][best_epoch]
    best_val_mae = history['val_mae'][best_epoch]

    print(f"\nЛучший MAE (train): {best_train_mae:.4f}")
    print(f"Лучший MAE (val): {best_val_mae:.4f}")

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(history['mae'], label='Train MAE', color='blue')
    axes[0].plot(history['val_mae'], label='Val MAE', color='red')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('MAE')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['loss'], label='Train Loss', color='blue')
    axes[1].plot(history['val_loss'], label='Val Loss', color='red')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss (MSE)')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

    return model, history

model = RegressionModel(input_dim=X_train.shape[1])
model, history = train_model(
    model, X_train, y_train, X_val, y_val,
    epochs=500, batch_size=16, lr=0.0001, patience=50
)

# %% [markdown]
# ### Обучение на модели RandomForest

# %%
pipeline = Pipeline([
    ('regressor', RandomForestRegressor(random_state=42, n_jobs=-1))
])

param_distributions = {
    'regressor__n_estimators': randint(150, 200, 250),
    'regressor__max_depth': [15, 20],
    'regressor__min_samples_split': randint(2, 11),
    'regressor__min_samples_leaf': randint(1, 6),
    'regressor__max_features': ['sqrt'],
    'regressor__bootstrap': [True],
    #'regressor__min_impurity_decrease': uniform(0.0, 0.1),
}

#cv = KFold(n_splits=3, shuffle=True, random_state=42)
split_indices = np.full(X_combined.shape[0], -1)
split_indices[val_idx] = 0
ps = PredefinedSplit(split_indices)

random_search = RandomizedSearchCV(
    pipeline,
    param_distributions,
    n_iter=5,
    cv=ps,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    random_state=42,
    verbose=0
)

random_search.fit(X_combined, y)
#random_search.fit(X_train, y_train)

y_pred_rf = random_search.predict(X_val)
val_mae = mean_absolute_error(y_val, y_pred_rf)

print(f'Лучший MAE: {-random_search.best_score_:.4f}')

best_model_rf = random_search.best_estimator_

# %% [markdown]
# ### Обучение на модели CatBoost

# %%
pipeline_cat = Pipeline([
    ('regressor', CatBoostRegressor(random_state=42, verbose=2))
])

param_distributions_cat = {
    'regressor__iterations': [200, 300],
    'regressor__learning_rate': [0.03, 0.05, 0.07],
    'regressor__depth': [4, 6],
    'regressor__l2_leaf_reg': [1, 3, 5],
    'regressor__subsample': [0.8, 0.9],
}

random_search_cat = RandomizedSearchCV(
    pipeline_cat,
    param_distributions_cat,
    n_iter=5,
    cv=ps,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    random_state=42,
    verbose=0
)
random_search_cat.fit(X_combined, y)
#random_search_cat.fit(X_train, y_train)

y_pred_cat = random_search_cat.predict(X_val)

print(f'CatBoost MAE: {-random_search.best_score_:.4f}')
best_catboost = random_search_cat.best_estimator_

# %% [markdown]
# ### Промежуточный вывод
#
# На подготовленных данных были обучены 3 различных модели. Лучший результат по MAE == 0.154 на валидации показала полносвязная нейроная сеть с 3мя скрытыми слоями. Используем ее для тестирования.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# ### Подготовка тестовых данных
#
# - Векторизация тестовых текстов
# - Векторизация тестовых изображений
# - Нормализация тестовых изображений

# %%
test_img_gen = load_images_pytorch(df_test_i, f'{data_path}/test_images')

all_test_features = []
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
feature_extractor = feature_extractor.to(device)

with torch.no_grad():
    for batch_images in test_img_gen:
        batch_images = batch_images.to(device)
        batch_features = feature_extractor(batch_images)
        all_test_features.append(batch_features.cpu())

test_features = torch.cat(all_test_features, dim=0).numpy()

print(f'Форма эмбедингов тестовых изображений: {test_features.shape}')

text_norm_test = Normalizer(norm='l2').transform(sbert_test)
image_norm_test = Normalizer(norm='l2').transform(test_features)

print(f'Форма эмбедингов нормализованных тестовых текстов: {text_norm_test.shape}')
print()
print(f'Форма эмбедингов нормализованных тестовых изображений: {image_norm_test.shape}')

# %% [markdown]
# ### Функция тестирования

# %%
def find_best_image(query, model, sbert_model, image_norm_test, test_images, data_path, top_k=3, pattern=None):
    if pattern and re.search(pattern, query, flags=re.IGNORECASE):
        print('⎢ This image is unavailable in your country in compliance with local laws.')
        return

    query_emb = sbert_model.encode([query])
    query_emb_norm = Normalizer(norm='l2').transform(query_emb)

    num_images = image_norm_test.shape[0]
    query_repeated = np.repeat(query_emb_norm, num_images, axis=0)
    batch_for_prediction = np.hstack([query_repeated, image_norm_test])

    import torch
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    model.eval()

    tensor_batch = torch.tensor(batch_for_prediction, dtype=torch.float32).to(device)

    with torch.no_grad():
        raw_preds = model(tensor_batch)
        preds = torch.sigmoid(raw_preds).cpu().numpy().flatten()

    best_indices = preds.argsort()[-top_k:][::-1]

    import matplotlib.pyplot as plt
    from PIL import Image

    plt.figure(figsize=(6 * top_k, 6))

    for i, idx in enumerate(best_indices):
        score = preds[idx]
        img_filename = test_images['image'].iloc[idx] if hasattr(test_images, 'iloc') else test_images[idx]
        img_path = f"{data_path}/test_images/{img_filename}"

        try:
            img = Image.open(img_path)
            plt.subplot(1, top_k, i + 1)
            plt.imshow(img)
            plt.axis('off')
        except Exception as e:
            print(f'Ошибка загрузки: {img_path} — {e}')

    plt.tight_layout()
    plt.show()

# %%
find_best_image(
    query='A brown dog is sitting in some long grass',
    model=model,
    sbert_model=sbert,
    image_norm_test=image_norm_test,
    test_images=df_test_i,
    data_path=data_path,
    top_k=3,
    pattern=pattern
)

# %%
sample_text = df_test_q.sample(1)['query_text'].iloc[0]
display(sample_text)

find_best_image(
    query=sample_text,
    model=model,
    sbert_model=sbert,
    image_norm_test=image_norm_test,
    test_images=df_test_i,
    data_path=data_path,
    top_k=3,
    pattern=pattern
)

# %%
test_queries = df_test_q.sample(10, random_state=42)['query_text'].tolist()

for i, query in enumerate(test_queries):
    print(f'Запрос: {query}\n')

    find_best_image(
        query=query,
        model=model,
        sbert_model=sbert,
        image_norm_test=image_norm_test,
        test_images=df_test_i,
        data_path=data_path,
        top_k=1,
        pattern=pattern
    )

# %% [markdown]
# ## Вывод
#
# Модель показывает улучшенные результаты в сопоставлении текста и изображений, но пока не способна полностью уловить все закономерности. Вероятные причины — небольшой объём обучающих данных и субъективность оценок экспертов при описании картинок. Эти факторы объясняют, почему модель иногда даёт неполностью корректные прогнозы.

# %% [markdown]
# ## Дополнительно попробовал другой подход, используем предобученую модель CLIP

# %% [markdown]
# Данную модель обучили на гигантском датасете из 400 миллионов пар (изображение + текст), собранных из интернета. Используем готовые ее, чтобы превратить наши картинки и текст в векторы. Предположу, что результаты должны быть в разы качественнее

# %%
clip_model = SentenceTransformer('clip-ViT-B-32')

# Создание эмбеддингов изображений
test_image_paths = [f'{test_images}/{img}' for img in df_test_i['image'].tolist()]

# Функция получения эмбеддингов
def get_image_embeddings_clip(image_paths, batch_size=32):
    embeddings = []
    for i in tqdm(range(0, len(image_paths), batch_size), desc='Векторизация фото'):
        batch_paths = image_paths[i:i+batch_size]
        batch_images = [Image.open(path).convert('RGB') for path in batch_paths]
        batch_embeddings = clip_model.encode(batch_images, convert_to_tensor=True, show_progress_bar=False)
        embeddings.append(batch_embeddings.cpu().numpy())
    return np.vstack(embeddings)

# Получаем эмбеддинги
image_embeddings_clip = get_image_embeddings_clip(test_image_paths)

# Создание индекса FAISS для быстрого поиска
faiss.normalize_L2(image_embeddings_clip)

# Создаем индекс
dimension = image_embeddings_clip.shape[1]
index = faiss.IndexFlatIP(dimension)
index.add(image_embeddings_clip)


# Функция поиска
def search_clip(query, top_k=3):

    query_embedding = clip_model.encode(query, convert_to_tensor=True)
    query_embedding = query_embedding.cpu().numpy().reshape(1, -1)


    faiss.normalize_L2(query_embedding)


    scores, indices = index.search(query_embedding, top_k)

    results = []
    for idx, score in zip(indices[0], scores[0]):
        img_name = df_test_i.iloc[idx]['image']
        img_path = f'{test_images}/{img_name}'
        results.append((img_path, score))

    return results

# Визуализируем
def visualize_results_clip(query, results):
    if not results:
        return

    fig, axes = plt.subplots(1, len(results), figsize=(15, 5))
    if len(results) == 1:
        axes = [axes]

    for i, (img_path, score) in enumerate(results):
        img = Image.open(img_path)
        axes[i].imshow(img)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# Фильтрация
def search_clip_safe(query, top_k=3):
    query_lower = query.lower()
    if any(keyword in query_lower for keyword in words):
        print("⚠️ This image is unavailable in your country in compliance with local laws.")
        return []

    return search_clip(query, top_k)

# %%
# Тестирование
test_queries_sample = df_test_q['query_text'].sample(5).tolist()

for query in test_queries_sample:
    print(f'\nЗапрос: {query[:100]}...')
    results = search_clip_safe(query, top_k=1)
    visualize_results_clip(query, results)

# %% [markdown]
# Скорость и точность впечатляет
